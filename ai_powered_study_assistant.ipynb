# %% [markdown]
# ## Install Python Libraries

# %%
# !pip install -U google-genai
# Out:
# Requirement already satisfied: google-genai in /usr/local/lib/python3.12/dist-packages (1.68.0)
# Collecting google-genai
#   Downloading google_genai-2.6.0-py3-none-any.whl.metadata (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from google-genai) (4.13.0)
# Collecting google-auth<3.0.0,>=2.48.1 (from google-auth[requests]<3.0.0,>=2.48.1->google-genai)
#   Downloading google_auth-2.53.0-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in /usr/local/lib/python3.12/dist-packages (from google-genai) (2.12.3)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai) (2.32.4)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in /usr/local/lib/python3.12/dist-packages (from google-genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.15)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (48.0.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.5.0)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (2.0.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (0.6.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (3.0)
# Downloading google_genai-2.6.0-py3-none-any.whl (821 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.0/821.0 kB 18.8 MB/s eta 0:00:00
# Downloading google_auth-2.53.0-py3-none-any.whl (246 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.1/246.1 kB 7.3 MB/s eta 0:00:00
# Installing collected packages: google-auth, google-genai
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.47.0
#     Uninstalling google-auth-2.47.0:
#       Successfully uninstalled google-auth-2.47.0
#   Attempting uninstall: google-genai
#     Found existing installation: google-genai 1.68.0
#     Uninstalling google-genai-1.68.0:
#       Successfully uninstalled google-genai-1.68.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.47.0, but you have google-auth 2.53.0 which is incompatible.
# google-adk 1.29.0 requires google-genai<2.0.0,>=1.64.0, but you have google-genai 2.6.0 which is incompatible.
# Successfully installed google-auth-2.53.0 google-genai-2.6.0

# %%
# To install a Python library, use the `pip install` command.
# For example, to install the pandas library:
# !pip install pandas

# You can also install multiple libraries at once:
# !pip install numpy matplotlib

# %%
import google.generativeai as genai
from google.colab import userdata

# Fetch the API key from Colab secrets
api_key = userdata.get("Gemini_api_key")

# Initialize the Gemini client
client = genai.configure(api_key=api_key)

# %%
def study_assistant(user_prompt):
  """
  Sends a prompt to the Gemini model and gets a response.
  """
  model = genai.GenerativeModel('gemini-2.5-flash')
  response = model.generate_content(user_prompt)
  return response.text

# %%
# Ask the study assistant a question
user_question = input()
output = study_assistant(user_question)

# Print the result
print(output)
# Out:
# what is software engineering
# **Software engineering** is a systematic, disciplined, and quantifiable approach to the development, operation, and maintenance of software. It applies engineering principles and best practices to create high-quality, reliable, maintainable, and scalable software systems.
#
# In simpler terms, it's about building software not just by writing code, but by using a structured, organized, and professional approach, much like how traditional engineers build bridges or buildings.
#
# Here's a breakdown of its key aspects:
#
# 1.  **Engineering Discipline:**
#     *   **Systematic Approach:** It follows a defined process (like the Software Development Life Cycle - SDLC) rather than ad-hoc coding.
#     *   **Principles & Methodologies:** Utilizes established principles, methods, and tools for designing, implementing, testing, and managing software projects.
#     *   **Quantifiable:** Aims to measure progress, quality, cost, and time, allowing for better planning, estimation, and control.
#     *   **Problem-Solving:** Focuses on understanding complex problems and designing robust software solutions to address them.
#
# 2.  **Key Goals:**
#     *   **Reliability:** Software should perform consistently and correctly.
#     *   **Efficiency:** Software should use computing resources (CPU, memory, storage) effectively.
#     *   **Maintainability:** Software should be easy to understand, modify, and fix bugs in over time.
#     *   **Scalability:** Software should be able to handle increasing workloads or user numbers without significant degradation.
#     *   **Security:** Software should protect against unauthorized access, use, disclosure, disruption, modification, or destruction.
#     *   **Usability:** Software should be easy for its intended users to learn and operate.
#     *   **Cost-Effectiveness:** Delivering software that provides value within budget and time constraints.
#
# 3.  **The Software Development Life Cycle (SDLC):** While different models exist (Waterfall, Agile, Scrum, Kanban), a typical SDLC involves:
#     *   **Requirements Engineering:** Understanding and documenting what the software needs to do (features, functions, user needs).
#     *   **Design:** Planning the architecture, structure, interfaces, and data of the software.
#     *   **Implementation/Coding:** Writing the actual source code based on the design.
#     *   **Testing:** Verifying that the software works as expected and meets the requirements, identifying and fixing defects.
#     *   **Deployment:** Releasing the software to users or systems.
#     *   **Maintenance:** Ongoing activities like fixing bugs, adding new features, adapting to new environments, and improving performance after deployment.
#
# 4.  **Beyond Coding:**
#     While coding is a crucial part, software engineering encompasses much more, including:
#     *   Project management
#     *   Configuration management
#     *   Quality assurance
#     *   Risk management
#     *   User experience (UX) and user interface (UI) design
#     *   Software architecture
#     *   Tooling and automation
#     *   Team collaboration and communication
#
# **Analogy:**
# Think of building a house. "Just coding" would be like throwing bricks and wood together without a blueprint, a plan, or skilled craftsmen. Software engineering is like having architects, structural engineers, electricians, plumbers, and a project manager, all following a plan to build a sturdy, functional, and aesthetically pleasing house that meets the owner's needs and stands the test of time.
#
# In essence, software engineering elevates software development from an art or craft to a rigorous scientific and engineering discipline. It's crucial for managing the complexity of modern software systems and ensuring their quality, reliability, and long-term success.
